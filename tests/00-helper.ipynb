# %%
import keyboard

print(keyboard.__file__)
# Out:
# c:\Algo\Playground\25-01-image_sorting_software\.venv\Lib\site-packages\keyboard\__init__.py

# %%
print("Created \"Archived\" and \"Starred\" folders")
# Out:
# Created "Archived" and "Starred" folders

# %%
for i in range(10):
    print(f"{i % 3}")
# Out:
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
